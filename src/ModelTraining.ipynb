# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from transformers import (
    T5Tokenizer, 
    T5ForConditionalGeneration, 
    Trainer, 
    TrainingArguments, 
    TrainerCallback,
    DataCollatorForSeq2Seq
)
import torch
import os
from datasets import Dataset
import warnings
warnings.filterwarnings("ignore")

# --- Custom Callback for Epoch Progress ---
class EpochProgressCallback(TrainerCallback):
    def on_epoch_begin(self, args, state, control, **kwargs):
        print(f"\n--- Starting Epoch {int(state.epoch) + 1}/{int(state.num_train_epochs)} ---")
    
    def on_epoch_end(self, args, state, control, logs=None, **kwargs):
        if logs:
            print(f"--- Finished Epoch {int(state.epoch)} ---")
            print(f"Training Loss: {logs.get('train_loss', 'N/A'):.4f}")
            print(f"Validation Loss: {logs.get('eval_loss', 'N/A'):.4f}")
            print("--------------------------------------------------")

# --- Performance Optimization ---
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

if torch.cuda.is_available():
    torch.set_float32_matmul_precision('high')
    print("CUDA is available. GPU will be used for training.")
else:
    print("CUDA not available. Training will run on CPU, which will be significantly slower.")

# --- 1. Load and Validate Dataset ---
file_path = '../datasets/dataset_with_stances.csv'
try:
    stance_df = pd.read_csv(file_path)
    print(f"Loaded dataset with {len(stance_df)} rows")
    
    # Check for required columns
    required_cols = ['text', 'stance', 'sentiment']
    missing_cols = [col for col in required_cols if col not in stance_df.columns]
    if missing_cols:
        raise ValueError(f"Missing required columns: {missing_cols}")
    
    # Clean data
    initial_len = len(stance_df)
    stance_df = stance_df.dropna(subset=['text', 'stance', 'sentiment'])
    final_len = len(stance_df)
    print(f"Dropped {initial_len - final_len} rows with missing values")
    print(f"Final dataset size: {final_len} rows")
    
    # Validate stance and sentiment values
    unique_stances = stance_df['stance'].unique()
    unique_sentiments = stance_df['sentiment'].unique()
    print(f"Unique stances: {unique_stances}")
    print(f"Unique sentiments: {unique_sentiments}")
    
except FileNotFoundError:
    print(f"Error: File not found at '{file_path}'.")
    exit()
except Exception as e:
    print(f"Error loading dataset: {e}")
    exit()

# --- 2. Prepare Data for Multi-Task Learning ---
# Create balanced dataset for both tasks
df_stance = pd.DataFrame({
    'input_text': 'classify stance: ' + stance_df['text'].astype(str),
    'target_text': stance_df['stance'].astype(str),
    'task_type': 'stance'
})

df_sentiment = pd.DataFrame({
    'input_text': 'classify sentiment: ' + stance_df['text'].astype(str),
    'target_text': stance_df['sentiment'].astype(str),
    'task_type': 'sentiment'
})

# Combine datasets
pretrain_df = pd.concat([df_stance, df_sentiment], ignore_index=True)
print(f"Prepared multi-task dataset with {len(pretrain_df)} examples")
print(f"Stance examples: {len(df_stance)}, Sentiment examples: {len(df_sentiment)}")

# --- 3. Split the Dataset ---
train_df, val_df = train_test_split(
    pretrain_df, 
    test_size=0.15, 
    random_state=42, 
    stratify=pretrain_df['task_type']  # Ensure balanced split
)
print(f"Training set: {len(train_df)} examples")
print(f"Validation set: {len(val_df)} examples")

# --- 4. Initialize Tokenizer and Model ---
model_name = 'google/flan-t5-small'
print(f"Loading model: {model_name}")

try:
    tokenizer = T5Tokenizer.from_pretrained(model_name)
    model = T5ForConditionalGeneration.from_pretrained(model_name)
    model.to(device)
    print("Model and tokenizer loaded successfully")
except Exception as e:
    print(f"Error loading model: {e}")
    exit()

# --- 5. Improved Tokenization Function ---
def tokenize_function(examples):
    """Tokenize input and target texts with proper handling"""
    # Tokenize inputs
    model_inputs = tokenizer(
        examples['input_text'], 
        max_length=256,  # Increased from 128
        truncation=True, 
        padding='max_length',
        return_tensors=None  # Return lists, not tensors
    )
    
    # Tokenize targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(
            examples['target_text'], 
            max_length=32,  # Shorter for targets
            truncation=True, 
            padding='max_length',
            return_tensors=None
        )
    
    # Replace pad token ids in labels with -100 (ignored in loss calculation)
    labels_with_ignore_index = []
    for label_ids in labels['input_ids']:
        label_ids_with_ignore = [
            (label_id if label_id != tokenizer.pad_token_id else -100) 
            for label_id in label_ids
        ]
        labels_with_ignore_index.append(label_ids_with_ignore)
    
    model_inputs['labels'] = labels_with_ignore_index
    return model_inputs

# --- 6. Create and Tokenize Datasets ---
print("\nTokenizing datasets...")
try:
    train_dataset = Dataset.from_pandas(train_df)
    val_dataset = Dataset.from_pandas(val_df)
    
    # Apply tokenization
    train_tokenized = train_dataset.map(
        tokenize_function,
        batched=True,
        num_proc=min(4, os.cpu_count()),  # Limit processes
        remove_columns=train_dataset.column_names
    )
    
    val_tokenized = val_dataset.map(
        tokenize_function,
        batched=True,
        num_proc=min(4, os.cpu_count()),
        remove_columns=val_dataset.column_names
    )
    
    print("Tokenization completed successfully")
    
except Exception as e:
    print(f"Error during tokenization: {e}")
    exit()

# --- 7. Data Collator ---
data_collator = DataCollatorForSeq2Seq(
    tokenizer=tokenizer,
    model=model,
    padding=True,
    return_tensors="pt"
)

# --- 8. Training Arguments ---
output_dir = '../results/pretraining'
os.makedirs(output_dir, exist_ok=True)

training_args = TrainingArguments(
    output_dir=output_dir,
    
    # Training schedule
    num_train_epochs=5,  # Increased epochs
    per_device_train_batch_size=8,  # Reduced batch size
    per_device_eval_batch_size=8,
    gradient_accumulation_steps=2,  # Effective batch size = 8 * 2 = 16
    
    # Learning rate and optimization
    learning_rate=3e-4,  # Slightly higher learning rate
    warmup_steps=500,
    weight_decay=0.01,
    
    # Evaluation and saving
    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
    
    # Logging
    logging_dir='./logs',
    logging_steps=50,  # More frequent logging
    report_to=None,  # Disable wandb/tensorboard
    
    # Performance
    fp16=torch.cuda.is_available(),
    dataloader_num_workers=min(4, os.cpu_count()),
    
    # Regularization
    max_grad_norm=1.0,
    
    # Save space
    save_total_limit=2,  # Keep only best 2 checkpoints
)

# --- 9. Initialize Trainer ---
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_tokenized,
    eval_dataset=val_tokenized,
    data_collator=data_collator,
    callbacks=[EpochProgressCallback()]
)

# --- 10. Training ---
print("\n" + "="*50)
print("STARTING MODEL TRAINING")
print("="*50)

try:
    # Train the model
    trainer.train()
    print("\nTraining completed successfully!")
    
    # Evaluate final model
    print("\nEvaluating final model...")
    eval_results = trainer.evaluate()
    print(f"Final evaluation results: {eval_results}")
    
except Exception as e:
    print(f"Error during training: {e}")
    import traceback
    traceback.print_exc()

# --- 11. Save the Model ---
final_model_path = '../models/rumor_knowledge_model'
os.makedirs(final_model_path, exist_ok=True)

try:
    trainer.save_model(final_model_path)
    tokenizer.save_pretrained(final_model_path)
    print(f"\nModel saved successfully to: {final_model_path}")
    
    # Save training info
    training_info = {
        'model_name': model_name,
        'dataset_size': len(pretrain_df),
        'train_size': len(train_df),
        'val_size': len(val_df),
        'unique_stances': list(unique_stances),
        'unique_sentiments': list(unique_sentiments),
        'final_eval_loss': eval_results.get('eval_loss', 'N/A')
    }
    
    import json
    with open(os.path.join(final_model_path, 'training_info.json'), 'w') as f:
        json.dump(training_info, f, indent=2)
    
    print("Training information saved.")
    
except Exception as e:
    print(f"Error saving model: {e}")

print("\n" + "="*50)
print("TRAINING PROCESS COMPLETED")
print("="*50)
# Out:
# CUDA is available. GPU will be used for training.
# Successfully loaded and cleaned ../datasets/dataset_with_stances.csv
# Prepared a multi-task dataset with 99332 examples.
#
# Starting to pre-tokenize the entire dataset... This may take a moment.
# ...
# Map (num_proc=12): 100%|██████████| 9934/9934 [00:12<00:00, 780.76 examples/s]
# Pre-tokenization complete.
#
# Starting model pre-training...
#
# --- Starting Epoch 1/3 ---
#     <div>
#
#       <progress value='16764' max='16764' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [16764/16764 1:48:13, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>nan</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>nan</td>
#     </tr>
# ...

# %%
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration
import json
import os

class RumorAnalysisModel:
    def __init__(self, model_path):
        """Initialize the rumor analysis model"""
        self.model_path = model_path
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        
        # Load model and tokenizer
        self.load_model()
        
        # Load training info if available
        self.load_training_info()
    
    def load_model(self):
        """Load the trained model and tokenizer"""
        try:
            print(f"Loading model from: {self.model_path}")
            self.tokenizer = T5Tokenizer.from_pretrained(self.model_path)
            self.model = T5ForConditionalGeneration.from_pretrained(self.model_path)
            self.model.to(self.device)
            self.model.eval()
            print(f"Model loaded successfully on {self.device}")
            
        except Exception as e:
            print(f"Error loading model: {e}")
            raise
    
    def load_training_info(self):
        """Load training information if available"""
        info_path = os.path.join(self.model_path, 'training_info.json')
        if os.path.exists(info_path):
            with open(info_path, 'r') as f:
                self.training_info = json.load(f)
                print(f"Training info loaded: {self.training_info}")
        else:
            self.training_info = None
            print("No training info found")
    
    def predict_stance(self, text):
        """Predict stance for given text"""
        return self._predict(f"classify stance: {text}")
    
    def predict_sentiment(self, text):
        """Predict sentiment for given text"""
        return self._predict(f"classify sentiment: {text}")
    
    def predict_both(self, text):
        """Predict both stance and sentiment for given text"""
        stance = self.predict_stance(text)
        sentiment = self.predict_sentiment(text)
        return {
            'text': text,
            'stance': stance,
            'sentiment': sentiment
        }
    
    def _predict(self, input_text):
        """Internal prediction function"""
        try:
            # Tokenize input
            inputs = self.tokenizer(
                input_text,
                return_tensors="pt",
                max_length=256,
                truncation=True,
                padding=True
            ).to(self.device)
            
            # Generate prediction
            with torch.no_grad():
                outputs = self.model.generate(
                    **inputs,
                    max_length=32,
                    num_beams=4,
                    do_sample=False,
                    early_stopping=True,
                    pad_token_id=self.tokenizer.pad_token_id,
                    eos_token_id=self.tokenizer.eos_token_id
                )
            
            # Decode prediction
            prediction = self.tokenizer.decode(outputs[0], skip_special_tokens=True)
            return prediction.strip()
            
        except Exception as e:
            print(f"Error during prediction: {e}")
            return "error"
    
    def analyze_rumor_conversation(self, texts):
        """Analyze multiple texts (e.g., a conversation thread)"""
        results = []
        for i, text in enumerate(texts):
            result = self.predict_both(text)
            result['index'] = i
            results.append(result)
        return results
    
    def get_model_info(self):
        """Get information about the loaded model"""
        info = {
            'model_path': self.model_path,
            'device': str(self.device),
            'model_type': type(self.model).__name__,
            'tokenizer_type': type(self.tokenizer).__name__
        }
        if self.training_info:
            info.update(self.training_info)
        return info

def test_model():
    """Test the model with sample data"""
    model_path = '../models/rumor_knowledge_model'
    
    # Check if model exists
    if not os.path.exists(model_path):
        print(f"Model not found at {model_path}")
        print("Please run the training script first.")
        return
    
    # Initialize model
    try:
        analyzer = RumorAnalysisModel(model_path)
        print("Model initialized successfully!")
        
        # Print model info
        print("\n" + "="*50)
        print("MODEL INFORMATION")
        print("="*50)
        info = analyzer.get_model_info()
        for key, value in info.items():
            print(f"{key}: {value}")
        
        # Test with sample texts
        print("\n" + "="*50)
        print("TESTING MODEL PREDICTIONS")
        print("="*50)
        
        test_texts = [
            "Charlie Hebdo became well known for publishing the Muhammed cartoons two years ago",
            "Black teenage boys are not men. They are children. Stop referring to a 17 year old as a man.",
            "This is completely false information and should not be believed.",
            "I'm not sure about this claim, can someone verify?",
            "This makes me really angry and upset!"
        ]
        
        for i, text in enumerate(test_texts, 1):
            print(f"\nTest {i}:")
            print(f"Text: {text}")
            
            result = analyzer.predict_both(text)
            print(f"Stance: {result['stance']}")
            print(f"Sentiment: {result['sentiment']}")
            print("-" * 30)
        
        # Test conversation analysis
        print("\n" + "="*50)
        print("TESTING CONVERSATION ANALYSIS")
        print("="*50)
        
        conversation = [
            "There was a shooting at Charlie Hebdo today",
            "This is terrible news, my thoughts are with the victims",
            "I don't believe this is real, seems fake to me",
            "Can someone confirm if this is actually happening?"
        ]
        
        results = analyzer.analyze_rumor_conversation(conversation)
        for result in results:
            print(f"Post {result['index'] + 1}: {result['text'][:50]}...")
            print(f"  Stance: {result['stance']}, Sentiment: {result['sentiment']}")
        
        print("\nModel testing completed successfully!")
        
    except Exception as e:
        print(f"Error testing model: {e}")
        import traceback
        traceback.print_exc()

if __name__ == "__main__":
    test_model()

# %%
import os
import pandas as pd
import json
import torch
from pathlib import Path

def check_dataset():
    """Check the dataset structure and content"""
    print("="*50)
    print("DATASET DIAGNOSTICS")
    print("="*50)
    
    dataset_path = '../datasets/dataset_with_stances.csv'
    
    if not os.path.exists(dataset_path):
        print(f"❌ Dataset not found at: {dataset_path}")
        
        # Check for alternative paths
        alt_paths = [
            'datasets/dataset_with_stances.csv',
            '../datasets/final_rumor_dataset_for_training.csv',
            'datasets/final_rumor_dataset_for_training.csv'
        ]
        
        for alt_path in alt_paths:
            if os.path.exists(alt_path):
                print(f"✅ Found alternative dataset at: {alt_path}")
                dataset_path = alt_path
                break
        else:
            print("❌ No dataset found in common locations")
            return None
    
    try:
        df = pd.read_csv(dataset_path)
        print(f"✅ Dataset loaded successfully")
        print(f"📊 Dataset shape: {df.shape}")
        print(f"📋 Columns: {list(df.columns)}")
        
        # Check for required columns
        required_cols = ['text', 'stance', 'sentiment']
        missing_cols = [col for col in required_cols if col not in df.columns]
        
        if missing_cols:
            print(f"❌ Missing required columns: {missing_cols}")
        else:
            print("✅ All required columns present")
        
        # Check data quality
        print("\n--- Data Quality ---")
        for col in required_cols:
            if col in df.columns:
                null_count = df[col].isnull().sum()
                unique_count = df[col].nunique()
                print(f"{col}: {null_count} nulls, {unique_count} unique values")
                
                if col in ['stance', 'sentiment']:
                    print(f"  Unique {col} values: {list(df[col].unique())}")
        
        print(f"\n--- Sample Data ---")
        print(df.head(3))
        
        return df
        
    except Exception as e:
        print(f"❌ Error loading dataset: {e}")
        return None

def check_model():
    """Check if the model exists and can be loaded"""
    print("\n" + "="*50)
    print("MODEL DIAGNOSTICS") 
    print("="*50)
    
    model_paths = [
        '../models/rumor_knowledge_model',
        'models/rumor_knowledge_model',
        '../results/pretraining'
    ]
    
    model_found = False
    
    for model_path in model_paths:
        if os.path.exists(model_path):
            print(f"✅ Model directory found at: {model_path}")
            model_found = True
            
            # Check model files
            required_files = ['config.json', 'pytorch_model.bin', 'tokenizer.json']
            for file in required_files:
                file_path = os.path.join(model_path, file)
                if os.path.exists(file_path):
                    print(f"  ✅ {file}")
                else:
                    print(f"  ❌ {file}")
            
            # Check training info
            training_info_path = os.path.join(model_path, 'training_info.json')
            if os.path.exists(training_info_path):
                print(f"  ✅ training_info.json")
                try:
                    with open(training_info_path, 'r') as f:
                        info = json.load(f)
                        print(f"     Training dataset size: {info.get('dataset_size', 'N/A')}")
                        print(f"     Final eval loss: {info.get('final_eval_loss', 'N/A')}")
                except:
                    print(f"  ❌ Could not read training_info.json")
            else:
                print(f"  ❌ training_info.json")
            
            # Try to load the model
            print(f"\n--- Testing Model Loading ---")
            try:
                from transformers import T5Tokenizer, T5ForConditionalGeneration
                
                tokenizer = T5Tokenizer.from_pretrained(model_path)
                model = T5ForConditionalGeneration.from_pretrained(model_path)
                print(f"✅ Model and tokenizer loaded successfully")
                print(f"   Model parameters: {model.num_parameters():,}")
                
                # Test a simple prediction
                test_text = "classify stance: This is a test message"
                inputs = tokenizer(test_text, return_tensors="pt", max_length=128, truncation=True)
                
                with torch.no_grad():
                    outputs = model.generate(**inputs, max_length=32, num_beams=2)
                    prediction = tokenizer.decode(outputs[0], skip_special_tokens=True)
                    print(f"✅ Test prediction successful: '{prediction}'")
                
                break
                
            except Exception as e:
                print(f"❌ Error loading model: {e}")
    
    if not model_found:
        print("❌ No model found in common locations")
        print("   You need to train the model first using the corrected training script")

def check_environment():
    """Check the Python environment and dependencies"""
    print("\n" + "="*50)
    print("ENVIRONMENT DIAGNOSTICS")
    print("="*50)
    
    # Check Python version
    import sys
    print(f"Python version: {sys.version}")
    
    # Check key dependencies
    dependencies = [
        'torch', 'transformers', 'datasets', 'pandas', 
        'numpy', 'sklearn', 'vaderSentiment'
    ]
    
    for dep in dependencies:
        try:
            module = __import__(dep)
            version = getattr(module, '__version__', 'unknown')
            print(f"✅ {dep}: {version}")
        except ImportError:
            print(f"❌ {dep}: not installed")
    
    # Check CUDA
    if torch.cuda.is_available():
        print(f"✅ CUDA available: {torch.version.cuda}")
        print(f"   GPU count: {torch.cuda.device_count()}")
        print(f"   Current device: {torch.cuda.current_device()}")
    else:
        print(f"❌ CUDA not available (CPU training will be very slow)")

def main():
    """Run all diagnostics"""
    print("🔍 RUMOR ANALYSIS MODEL DIAGNOSTICS")
    print("🔍 " + "="*48)
    
    # Check environment
    check_environment()
    
    # Check dataset
    dataset = check_dataset()
    
    # Check model
    check_model()
    
    print("\n" + "="*50)
    print("RECOMMENDATIONS")
    print("="*50)
    
    if dataset is None:
        print("1. ❌ Dataset issue: Make sure your dataset is properly processed")
        print("   Run the RumorData.ipynb notebook to create the dataset")
    else:
        print("1. ✅ Dataset looks good")
    
    if not os.path.exists('../models/rumor_knowledge_model'):
        print("2. ❌ Model not found: Train the model using the corrected script")
        print("   Use the corrected ModelTraining.py script provided")
    else:
        print("2. ✅ Model directory exists")
    
    print("3. 💡 If training failed with 0.0 loss, it's likely due to:")
    print("   - Incorrect loss calculation (fixed in corrected script)")
    print("   - Labels not properly formatted (fixed with -100 padding)")
    print("   - Data collator issues (added proper DataCollatorForSeq2Seq)")
    
    print("\n🚀 Next steps:")
    print("   1. Use the corrected training script")
    print("   2. Use the inference script to test your model")
    print("   3. Check model outputs make sense for your use case")

if __name__ == "__main__":
    main()
