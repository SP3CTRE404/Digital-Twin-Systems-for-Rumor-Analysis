# %%
import torch
import time
import gc
from transformers import T5Tokenizer, T5ForConditionalGeneration
import numpy as np

def test_gpu_performance():
    """Test GPU performance for T5 training (auto-detects GPU)"""
    
    print("🔍 GPU PERFORMANCE TEST")
    print("=" * 50)
    
    # Check CUDA availability
    if not torch.cuda.is_available():
        print("❌ CUDA not available!")
        return False
    
    # GPU Info
    gpu_name = torch.cuda.get_device_name(0)
    gpu_memory = torch.cuda.get_device_properties(0).total_memory / 1024**3
    print(f"🚀 GPU: {gpu_name}")
    print(f"💾 GPU Memory: {gpu_memory:.1f} GB")
    print(f"🔧 CUDA Version: {torch.version.cuda}")
    print(f"⚡ PyTorch Version: {torch.__version__}")
    
    # Expectation check
    if "3050" not in gpu_name:
        print(f"⚠️ Warning: Expected RTX 3050, got {gpu_name}")
    if gpu_memory < 3.5:  # RTX 3050 Laptop GPU usually 4 GB
        print(f"⚠️ Warning: Very low VRAM detected ({gpu_memory:.1f}GB)")
    
    print("\n" + "=" * 50)
    print("🧪 PERFORMANCE TESTS")
    print("=" * 50)
    
    # Test 1: Basic GPU Operations
    print("\n1️⃣ Testing basic GPU operations...")
    try:
        start_time = time.time()
        a = torch.randn(1000, 1000, device='cuda', dtype=torch.float16)
        b = torch.randn(1000, 1000, device='cuda', dtype=torch.float16)
        c = torch.matmul(a, b)
        torch.cuda.synchronize()
        basic_time = time.time() - start_time
        
        print(f"✅ Matrix multiplication (1000x1000): {basic_time:.3f}s")
        
        memory_used = torch.cuda.memory_allocated() / 1024**3
        print(f"📊 GPU Memory used: {memory_used:.2f}GB")
        
        del a, b, c
        torch.cuda.empty_cache()
        
    except Exception as e:
        print(f"❌ Basic GPU test failed: {e}")
        return False
    
    # Test 2: T5 Model Loading Speed
    print("\n2️⃣ Testing T5 model loading speed...")
    try:
        start_time = time.time()
        tokenizer = T5Tokenizer.from_pretrained('google/flan-t5-small')
        model = T5ForConditionalGeneration.from_pretrained(
            'google/flan-t5-small',
            torch_dtype=torch.float16
        ).to('cuda')
        load_time = time.time() - start_time
        
        print(f"✅ T5-small loading time: {load_time:.2f}s")
        print(f"📏 Model parameters: {model.num_parameters():,}")
        
        memory_used = torch.cuda.memory_allocated() / 1024**3
        print(f"📊 GPU Memory after model load: {memory_used:.2f}GB")
        
    except Exception as e:
        print(f"❌ Model loading test failed: {e}")
        return False
    
    # Test 3: Inference Speed Test
    print("\n3️⃣ Testing inference speed...")
    try:
        model.eval()
        test_texts = [
            "stance: This is a test message for rumor detection",
            "sentiment: I am very happy about this news",
            "stance: This claim seems false to me"
        ] * 10  # 30 samples
        
        start_time = time.time()
        inputs = tokenizer(
            test_texts,
            return_tensors="pt",
            max_length=128,
            truncation=True,
            padding=True
        ).to('cuda')
        tokenize_time = time.time() - start_time
        print(f"✅ Batch tokenization (30 samples): {tokenize_time:.3f}s")
        
        start_time = time.time()
        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_length=16,
                num_beams=2,
                do_sample=False,
                pad_token_id=tokenizer.pad_token_id
            )
        torch.cuda.synchronize()
        inference_time = time.time() - start_time
        
        print(f"✅ Batch inference (30 samples): {inference_time:.3f}s")
        print(f"⚡ Inference speed: {len(test_texts)/inference_time:.1f} samples/sec")
        
        predictions = [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]
        print(f"🔤 Sample predictions: {predictions[:3]}")
        
    except Exception as e:
        print(f"❌ Inference test failed: {e}")
        return False
    
    # Test 4: Training Speed Simulation
    print("\n4️⃣ Testing training simulation...")
    try:
        model.train()
        optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)
        
        batch_size = 16  # lower batch size for 4 GB VRAM
        fake_input_ids = torch.randint(0, 1000, (batch_size, 128), device='cuda')
        fake_labels = torch.randint(0, 1000, (batch_size, 16), device='cuda')
        
        start_time = time.time()
        for step in range(5):  # 5 steps to keep memory safe
            optimizer.zero_grad()
            outputs = model(input_ids=fake_input_ids, labels=fake_labels)
            loss = outputs.loss
            loss.backward()
            optimizer.step()
            if step == 0:
                print(f"📊 Sample loss: {loss.item():.4f}")
        
        torch.cuda.synchronize()
        training_time = time.time() - start_time
        print(f"✅ Training simulation (5 steps, batch_size={batch_size}): {training_time:.3f}s")
        print(f"⚡ Training speed: {5/training_time:.2f} steps/sec")
        
    except Exception as e:
        print(f"❌ Training simulation failed: {e}")
        return False
    
    # Final memory check
    print("\n" + "=" * 50)
    print("📊 FINAL MEMORY STATUS")
    print("=" * 50)
    
    memory_allocated = torch.cuda.memory_allocated() / 1024**3
    memory_reserved = torch.cuda.memory_reserved() / 1024**3
    memory_total = torch.cuda.get_device_properties(0).total_memory / 1024**3
    
    print(f"💾 Memory Allocated: {memory_allocated:.2f}GB")
    print(f"💾 Memory Reserved: {memory_reserved:.2f}GB") 
    print(f"💾 Memory Total: {memory_total:.2f}GB")
    print(f"💾 Memory Usage: {(memory_allocated/memory_total)*100:.1f}%")
    
    del model, tokenizer, optimizer
    torch.cuda.empty_cache()
    gc.collect()
    
    print(f"\n✅ GPU performance test completed successfully!")
    print(f"🎯 Your RTX 3050 is working properly for small-model training")
    print(f"💡 Expect slower training (~30 min per epoch on T5-small).")
    
    return True

def check_optimization_settings():
    """Check if optimization settings are properly configured"""
    print("\n" + "=" * 50)
    print("⚙️ OPTIMIZATION SETTINGS CHECK")
    print("=" * 50)
    print(f"🔧 CUDNN Benchmark: {torch.backends.cudnn.benchmark}")
    print(f"🔧 TF32 (CUDA): {torch.backends.cuda.matmul.allow_tf32}")
    print(f"🔧 TF32 (CUDNN): {torch.backends.cudnn.allow_tf32}")
    
    print(f"\n💡 Applying recommended settings...")
    torch.backends.cudnn.benchmark = True
    torch.backends.cuda.matmul.allow_tf32 = True
    torch.backends.cudnn.allow_tf32 = True
    print(f"✅ Optimization settings applied!")

if __name__ == "__main__":
    check_optimization_settings()
    success = test_gpu_performance()
    if success:
        print(f"\n🚀 Your system is ready for training small transformer models!")
    else:
        print(f"\n❌ Performance test failed - check your GPU setup")
# Out:
# ==================================================
# ⚙️ OPTIMIZATION SETTINGS CHECK
# ==================================================
# 🔧 CUDNN Benchmark: True
# 🔧 TF32 (CUDA): True
# 🔧 TF32 (CUDNN): True
#
# 💡 Applying recommended settings...
# ✅ Optimization settings applied!
# 🔍 GPU PERFORMANCE TEST
# ==================================================
# 🚀 GPU: NVIDIA GeForce RTX 3050 Laptop GPU
# 💾 GPU Memory: 4.0 GB
# 🔧 CUDA Version: 12.9
# ⚡ PyTorch Version: 2.8.0+cu129
#
# ==================================================
# 🧪 PERFORMANCE TESTS
# ==================================================
#
# 1️⃣ Testing basic GPU operations...
# ✅ Matrix multiplication (1000x1000): 0.003s
# 📊 GPU Memory used: 1.46GB
#
# 2️⃣ Testing T5 model loading speed...
# ✅ T5-small loading time: 2.97s
# 📏 Model parameters: 76,961,152
# 📊 GPU Memory after model load: 1.62GB
#
# 3️⃣ Testing inference speed...
# ✅ Batch tokenization (30 samples): 0.005s
# ✅ Batch inference (30 samples): 0.404s
# ⚡ Inference speed: 74.3 samples/sec
# 🔤 Sample predictions: ['stance: This is a test message for rumor detection', 'positive', 'i. i. i. i. i.']
#
# 4️⃣ Testing training simulation...
# 📊 Sample loss: 12.0000
# ✅ Training simulation (5 steps, batch_size=16): 1.311s
# ⚡ Training speed: 3.81 steps/sec
#
# ==================================================
# 📊 FINAL MEMORY STATUS
# ==================================================
# 💾 Memory Allocated: 2.15GB
# 💾 Memory Reserved: 2.91GB
# 💾 Memory Total: 4.00GB
# 💾 Memory Usage: 53.8%
#
# ✅ GPU performance test completed successfully!
# 🎯 Your RTX 3050 is working properly for small-model training
# 💡 Expect slower training (~30 min per epoch on T5-small).
#
# 🚀 Your system is ready for training small transformer models!

# %%
import os
import gc
import warnings
import numpy as np
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    DataCollatorWithPadding,
    Trainer,
    TrainingArguments,
)

warnings.filterwarnings("ignore")

def optimize_gpu():
    if torch.cuda.is_available():
        torch.backends.cudnn.benchmark = True
        torch.backends.cuda.matmul.allow_tf32 = True
        torch.backends.cudnn.allow_tf32 = True
        torch.cuda.empty_cache()
        gpu_name = torch.cuda.get_device_name(0)
        gpu_memory = torch.cuda.get_device_properties(0).total_memory / 1024**3
        print(f"🚀 GPU: {gpu_name}")
        print(f"💾 GPU Memory: {gpu_memory:.1f} GB")
        print(f"🔧 CUDA Version: {torch.version.cuda}")
        os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'max_split_size_mb:64'
        return True
    else:
        print("❌ CUDA not available")
        return False

_ = optimize_gpu()

# 1) Load dataset
csv_path = '../datasets/dataset_with_stances.csv'
df = pd.read_csv(csv_path)
print(f"📊 Loaded dataset with {len(df)} rows")

# Keep only required columns and clean
df = df.dropna(subset=['text', 'sentiment']).copy()
# Optional row cap for VRAM
if len(df) > 20000:
    df = df.sample(n=20000, random_state=42).reset_index(drop=True)
    print(f"🎯 Using subset of {len(df)} rows for limited VRAM")

# Normalize labels
df['sentiment'] = df['sentiment'].astype(str).str.strip().str.lower()
label_order = ['negative', 'neutral', 'positive']
label_to_id = {l: i for i, l in enumerate(label_order)}
# Filter unexpected labels
valid_mask = df['sentiment'].isin(label_to_id.keys())
df = df[valid_mask].reset_index(drop=True)
print(f"✅ Cleaned dataset: {len(df)} rows")

# Train/val split
train_df, val_df = train_test_split(
    df, test_size=0.1, random_state=42, stratify=df['sentiment']
)
print(f"📊 Train: {len(train_df)}, Val: {len(val_df)}")

# 2) Tokenizer and model
model_name = 'distilbert-base-uncased'
tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)
num_labels = len(label_to_id)
model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    num_labels=num_labels,
    id2label={i: l for l, i in label_to_id.items()},
    label2id=label_to_id,
)

# 3) Build tokenized datasets
import datasets as hf_datasets

def tokenize_function(batch):
    return tokenizer(batch['text'], truncation=True, max_length=256)

def to_hf_dataset(frame):
    tmp = frame[['text', 'sentiment']].copy()
    tmp['labels'] = tmp['sentiment'].map(label_to_id).astype(int)
    ds = hf_datasets.Dataset.from_pandas(tmp, preserve_index=False)
    ds = ds.map(tokenize_function, batched=True, remove_columns=['text', 'sentiment'])
    return ds

train_ds = to_hf_dataset(train_df)
val_ds = to_hf_dataset(val_df)

# 4) Collator and metrics
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=-1)
    acc = accuracy_score(labels, preds)
    f1 = f1_score(labels, preds, average='macro')
    return {'accuracy': acc, 'f1_macro': f1}

# 5) Training args
output_dir = '../results/sentiment_training_3050'
os.makedirs(output_dir, exist_ok=True)
training_args = TrainingArguments(
    output_dir=output_dir,
    num_train_epochs=3,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=32,
    load_best_model_at_end=False,
    learning_rate=5e-5,
    weight_decay=0.01,
    logging_steps=50,
    fp16=False,
    report_to=[],
)

# 6) Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=val_ds,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

print("\n============================================================")
print("🚀 TRAINING SENTIMENT CLASSIFIER (DistilBERT)")
print("============================================================")
trainer.train()

# Explicit evaluation after training
preds = trainer.predict(val_ds)
y_true = preds.label_ids
y_pred = np.argmax(preds.predictions, axis=-1)
print({"accuracy": accuracy_score(y_true, y_pred), "f1_macro": f1_score(y_true, y_pred, average='macro')})

# 7) Save final model
final_dir = '../models/sentiment_model_3050'
os.makedirs(final_dir, exist_ok=True)
trainer.save_model(final_dir)
tokenizer.save_pretrained(final_dir)
print(f"💾 Sentiment model saved to: {final_dir}")

del model
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    gc.collect()
# Out:
# 🚀 GPU: NVIDIA GeForce RTX 3050 Laptop GPU
# 💾 GPU Memory: 4.0 GB
# 🔧 CUDA Version: 12.9
# 📊 Loaded dataset with 49666 rows
# 🎯 Using subset of 20000 rows for limited VRAM
# ✅ Cleaned dataset: 20000 rows
# 📊 Train: 18000, Val: 2000
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Map: 100%|██████████| 18000/18000 [00:00<00:00, 42672.53 examples/s]
# Map: 100%|██████████| 2000/2000 [00:00<00:00, 41089.41 examples/s]
# ============================================================
# 🚀 TRAINING SENTIMENT CLASSIFIER (DistilBERT)
# ============================================================
#     <div>
#
#       <progress value='3375' max='3375' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3375/3375 05:08, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.971200</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.834700</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.664700</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.596700</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.583400</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.598000</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.539900</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.473800</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.503600</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.457400</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.468000</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.464600</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.438900</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.395300</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.388900</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.398200</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.447800</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.423900</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.382000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.393200</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.435100</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.390500</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.376300</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.274600</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.284000</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.265200</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.282300</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.266000</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.223000</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.253400</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.257600</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.231600</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.226300</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.245500</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.290900</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.261100</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.209300</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.246200</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.238200</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.226000</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.254400</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.234100</td>
#     </tr>
#     <tr>
#       <td>2150</td>
#       <td>0.253200</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.196600</td>
#     </tr>
#     <tr>
#       <td>2250</td>
#       <td>0.213400</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.162000</td>
#     </tr>
#     <tr>
#       <td>2350</td>
#       <td>0.143500</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.137300</td>
#     </tr>
#     <tr>
#       <td>2450</td>
#       <td>0.117700</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.148900</td>
#     </tr>
#     <tr>
#       <td>2550</td>
#       <td>0.148400</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.149900</td>
#     </tr>
#     <tr>
#       <td>2650</td>
#       <td>0.143300</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.130500</td>
#     </tr>
#     <tr>
#       <td>2750</td>
#       <td>0.098300</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.166500</td>
#     </tr>
#     <tr>
#       <td>2850</td>
#       <td>0.182500</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.157000</td>
#     </tr>
#     <tr>
#       <td>2950</td>
#       <td>0.156900</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.114600</td>
#     </tr>
#     <tr>
#       <td>3050</td>
#       <td>0.160300</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.135500</td>
#     </tr>
#     <tr>
#       <td>3150</td>
#       <td>0.102200</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.127300</td>
#     </tr>
#     <tr>
#       <td>3250</td>
#       <td>0.095000</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.180300</td>
#     </tr>
#     <tr>
#       <td>3350</td>
#       <td>0.124200</td>
#     </tr>
#   </tbody>
# </table><p>
# {'accuracy': 0.897, 'f1_macro': 0.8954855883622619}
# 💾 Sentiment model saved to: ../models/sentiment_model_3050

# %%
import os
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification

MODEL_DIR = '../models/sentiment_model_3050'

class SentimentInference:
    def __init__(self, model_dir: str = MODEL_DIR):
        self.model_dir = model_dir
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        print(f"Loading sentiment model from: {self.model_dir}")
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_dir)
        self.model = AutoModelForSequenceClassification.from_pretrained(self.model_dir).to(self.device)
        self.model.eval()
        self.id_to_label = {int(k): v for k, v in self.model.config.id2label.items()}
        print(f"Model loaded on {self.device}. Labels: {self.id_to_label}")

    def predict(self, texts):
        if isinstance(texts, str):
            texts = [texts]
        enc = self.tokenizer(texts, padding=True, truncation=True, max_length=256, return_tensors='pt').to(self.device)
        with torch.no_grad():
            logits = self.model(**enc).logits
        preds = logits.argmax(dim=-1).cpu().numpy().tolist()
        return [self.id_to_label[int(i)] for i in preds]

if not os.path.exists(MODEL_DIR):
    print(f"Model not found at {MODEL_DIR}. Run the training cell first.")
else:
    inf = SentimentInference(MODEL_DIR)

    demo = [
        "I absolutely love this!",
        "This is terrible and I hate it.",
        "It's okay, nothing special.",
        "Not good, not bad.",
        "Brilliant result, very happy!",
    ]
    out = inf.predict(demo)
    for t, p in zip(demo, out):
        print(f"Text: {t}\nPred: {p}\n{'-'*30}")
# Out:
# Loading sentiment model from: ../models/sentiment_model_3050
# Model loaded on cuda. Labels: {0: 'negative', 1: 'neutral', 2: 'positive'}
# Text: I absolutely love this!
# Pred: positive
# ------------------------------
# Text: This is terrible and I hate it.
# Pred: negative
# ------------------------------
# Text: It's okay, nothing special.
# Pred: negative
# ------------------------------
# Text: Not good, not bad.
# Pred: positive
# ------------------------------
# Text: Brilliant result, very happy!
# Pred: positive
# ------------------------------

# %%
import os
import torch
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from sklearn.metrics import classification_report

class SentimentClassifier:
    def __init__(self, model_path: str):
        self.model_path = model_path
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.tokenizer = AutoTokenizer.from_pretrained(self.model_path)
        self.model = AutoModelForSequenceClassification.from_pretrained(self.model_path).to(self.device)
        self.model.eval()
        self.id_to_label = {int(k): v for k, v in self.model.config.id2label.items()}

    def predict(self, texts):
        if isinstance(texts, str):
            texts = [texts]
        enc = self.tokenizer(texts, padding=True, truncation=True, max_length=256, return_tensors='pt').to(self.device)
        with torch.no_grad():
            logits = self.model(**enc).logits
        preds = logits.argmax(dim=-1).cpu().numpy().tolist()
        return [self.id_to_label[int(i)] for i in preds]

# Load saved model
model_dir = '../models/sentiment_model_3050'
if not os.path.exists(model_dir):
    print(f"Model not found at {model_dir}. Run the training cell first.")
else:
    clf = SentimentClassifier(model_dir)
    print("Loaded sentiment model.")
    print(f"Labels: {clf.id_to_label}")

    # Sample predictions
    samples = [
        "I think the poilitical and economic state of this world is well and truly destroyed!",
        "This is terrible and I hate it.",
        "It's okay, nothing special.",
        "Not good, not bad.",
        "Brilliant result, very happy!",
    ]
    preds = clf.predict(samples)
    for t, p in zip(samples, preds):
        print(f"Text: {t}\nPredicted: {p}\n{'-'*30}")

    # Quick evaluation on a subset
    data_path = '../datasets/dataset_with_stances.csv'
    if os.path.exists(data_path):
        df = pd.read_csv(data_path)
        df = df.dropna(subset=['text', 'sentiment']).copy()
        df['sentiment'] = df['sentiment'].astype(str).str.strip().str.lower()
        df = df[df['sentiment'].isin(['negative', 'neutral', 'positive'])]
        df = df.sample(n=min(500, len(df)), random_state=42).reset_index(drop=True)
        y_true = df['sentiment'].tolist()
        y_pred = clf.predict(df['text'].tolist())
        print(classification_report(y_true, y_pred, labels=['negative','neutral','positive']))
    else:
        print("Dataset not found for quick eval; skipped.")
# Out:
# Loaded sentiment model.
# Labels: {0: 'negative', 1: 'neutral', 2: 'positive'}
# Text: I think the poilitical and economic state of this world is well and truly destroyed!
# Predicted: negative
# ------------------------------
# Text: This is terrible and I hate it.
# Predicted: negative
# ------------------------------
# Text: It's okay, nothing special.
# Predicted: negative
# ------------------------------
# Text: Not good, not bad.
# Predicted: positive
# ------------------------------
# Text: Brilliant result, very happy!
# Predicted: positive
# ------------------------------
#               precision    recall  f1-score   support
#
#     negative       0.97      0.98      0.97       198
#      neutral       0.99      0.90      0.95       143
#     positive       0.94      1.00      0.97       159
#
#     accuracy                           0.96       500
#    macro avg       0.97      0.96      0.96       500
# weighted avg       0.97      0.96      0.96       500

# %%
import os
import gc
import json
import warnings
import numpy as np
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, classification_report
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    DataCollatorWithPadding,
    Trainer,
    TrainingArguments,
)
import datasets as hf_datasets

warnings.filterwarnings("ignore")

def optimize_gpu():
    """Optimize GPU settings for RTX 3050"""
    if torch.cuda.is_available():
        torch.backends.cudnn.benchmark = True
        torch.backends.cuda.matmul.allow_tf32 = True
        torch.backends.cudnn.allow_tf32 = True
        torch.cuda.empty_cache()
        gpu_name = torch.cuda.get_device_name(0)
        gpu_memory = torch.cuda.get_device_properties(0).total_memory / 1024**3
        print(f"🚀 GPU: {gpu_name}")
        print(f"💾 GPU Memory: {gpu_memory:.1f} GB")
        print(f"🔧 CUDA Version: {torch.version.cuda}")
        os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'max_split_size_mb:64'
        return True
    else:
        print("❌ CUDA not available")
        return False

def train_stance_detection_model():
    """Train stance detection model optimized for RTX 3050"""
    
    # Initialize GPU optimization
    _ = optimize_gpu()
    
    # 1. Load and prepare dataset
    print("Loading dataset for stance detection...")
    csv_path = '../datasets/dataset_with_stances.csv'
    
    if not os.path.exists(csv_path):
        print(f"Dataset not found at {csv_path}")
        print("Please ensure the dataset exists with 'text' and 'stance' columns")
        return None
    
    df = pd.read_csv(csv_path)
    print(f"📊 Loaded dataset with {len(df)} rows")
    
    # Clean and prepare stance data
    df = df.dropna(subset=['text', 'stance']).copy()
    
    # Normalize stance labels
    stance_mapping = {
        'support': 'support',
        'deny': 'deny', 
        'query': 'query',
        'comment': 'comment',
        # Handle any variations
        'agree': 'support',
        'disagree': 'deny',
        'question': 'query',
        'neutral': 'comment'
    }
    
    df['stance_clean'] = df['stance'].astype(str).str.strip().str.lower()
    df['stance_clean'] = df['stance_clean'].map(stance_mapping)
    
    # Remove unmapped stances
    df = df.dropna(subset=['stance_clean']).copy()
    
    # If dataset is large, sample for RTX 3050 (limited VRAM)
    if len(df) > 15000:
        df = df.sample(n=15000, random_state=42).reset_index(drop=True)
        print(f"🎯 Using subset of {len(df)} rows for RTX 3050 VRAM limits")
    
    print(f"✅ Cleaned dataset: {len(df)} rows")
    
    # Check stance distribution
    stance_counts = df['stance_clean'].value_counts()
    print(f"📊 Stance distribution:")
    for stance, count in stance_counts.items():
        print(f"  {stance}: {count} ({count/len(df)*100:.1f}%)")
    
    # Create label mappings
    unique_stances = sorted(df['stance_clean'].unique())
    label_to_id = {label: idx for idx, label in enumerate(unique_stances)}
    id_to_label = {idx: label for label, idx in label_to_id.items()}
    
    print(f"🏷️ Stance labels: {unique_stances}")
    
    # Train/validation split
    train_df, val_df = train_test_split(
        df, test_size=0.15, random_state=42, stratify=df['stance_clean']
    )
    print(f"📊 Train: {len(train_df)}, Val: {len(val_df)}")
    
    # 2. Initialize model and tokenizer
    model_name = 'distilbert-base-uncased'  # Good balance of performance and speed
    tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)
    
    num_labels = len(unique_stances)
    model = AutoModelForSequenceClassification.from_pretrained(
        model_name,
        num_labels=num_labels,
        id2label=id_to_label,
        label2id=label_to_id,
    )
    
    # 3. Tokenization
    def tokenize_function(batch):
        return tokenizer(batch['text'], truncation=True, max_length=256)
    
    def prepare_dataset(dataframe):
        """Convert dataframe to HuggingFace dataset"""
        tmp = dataframe[['text', 'stance_clean']].copy()
        tmp['labels'] = tmp['stance_clean'].map(label_to_id).astype(int)
        
        ds = hf_datasets.Dataset.from_pandas(tmp, preserve_index=False)
        ds = ds.map(tokenize_function, batched=True, remove_columns=['text', 'stance_clean'])
        return ds
    
    print("Tokenizing datasets...")
    train_dataset = prepare_dataset(train_df)
    val_dataset = prepare_dataset(val_df)
    
    # 4. Data collator and metrics
    data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
    
    def compute_metrics(eval_pred):
        """Compute accuracy and F1 metrics"""
        logits, labels = eval_pred
        predictions = np.argmax(logits, axis=-1)
        
        accuracy = accuracy_score(labels, predictions)
        f1_macro = f1_score(labels, predictions, average='macro')
        f1_weighted = f1_score(labels, predictions, average='weighted')
        
        return {
            'accuracy': accuracy,
            'f1_macro': f1_macro,
            'f1_weighted': f1_weighted
        }
    
    # 5. Training configuration (optimized for RTX 3050)
    output_dir = '../results/stance_training_3050'
    os.makedirs(output_dir, exist_ok=True)
    
    training_args = TrainingArguments(
        output_dir=output_dir,
        num_train_epochs=4,
        per_device_train_batch_size=12,  # Conservative for 4GB VRAM
        per_device_eval_batch_size=16,
        gradient_accumulation_steps=2,   # Effective batch size = 24
        
        learning_rate=3e-5,
        weight_decay=0.01,
        warmup_ratio=0.1,
        
        eval_strategy="epoch",  # Changed from evaluation_strategy
        save_strategy="epoch",
        load_best_model_at_end=True,
        metric_for_best_model="f1_weighted",
        greater_is_better=True,
        
        logging_steps=50,
        logging_dir='./logs',
        report_to=[],
        
        fp16=False,  # Sometimes causes issues on RTX 3050
        dataloader_num_workers=2,
        save_total_limit=2,
        
        remove_unused_columns=True,
    )
    
    # 6. Initialize trainer
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=val_dataset,
        tokenizer=tokenizer,
        data_collator=data_collator,
        compute_metrics=compute_metrics,
    )
    
    print("\n" + "="*60)
    print("🚀 TRAINING STANCE DETECTION MODEL (DistilBERT)")
    print("="*60)
    
    # 7. Training
    try:
        trainer.train()
        print("✅ Training completed successfully!")
        
        # Final evaluation
        eval_results = trainer.evaluate()
        print(f"📊 Final Evaluation Results:")
        for metric, value in eval_results.items():
            print(f"  {metric}: {value:.4f}")
        
    except Exception as e:
        print(f"❌ Training failed: {e}")
        return None
    
    # 8. Detailed evaluation on test set
    print("\n" + "="*60)
    print("📊 DETAILED EVALUATION")
    print("="*60)
    
    # Predict on validation set
    predictions = trainer.predict(val_dataset)
    y_true = predictions.label_ids
    y_pred = np.argmax(predictions.predictions, axis=-1)
    
    # Classification report
    target_names = [id_to_label[i] for i in range(len(unique_stances))]
    report = classification_report(y_true, y_pred, target_names=target_names, digits=4)
    print("Classification Report:")
    print(report)
    
    # 9. Save the model
    final_model_path = '../models/stance_model_3050'
    os.makedirs(final_model_path, exist_ok=True)
    
    trainer.save_model(final_model_path)
    tokenizer.save_pretrained(final_model_path)
    
    # Save label mappings
    label_info = {
        'label_to_id': label_to_id,
        'id_to_label': id_to_label,
        'unique_stances': unique_stances
    }
    
    import json
    with open(os.path.join(final_model_path, 'label_mappings.json'), 'w') as f:
        json.dump(label_info, f, indent=2)
    
    print(f"💾 Stance detection model saved to: {final_model_path}")
    
    # 10. Memory cleanup
    del model, trainer
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        gc.collect()
    
    print("✅ Stance detection training completed!")
    return final_model_path

class StanceClassifier:
    """Inference class for stance detection"""
    
    def __init__(self, model_path="../models/stance_model_3050"):
        """Initialize stance classifier"""
        self.model_path = model_path
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        
        if not os.path.exists(model_path):
            raise FileNotFoundError(f"Model not found at {model_path}")
        
        # Load model and tokenizer
        self.tokenizer = AutoTokenizer.from_pretrained(model_path)
        self.model = AutoModelForSequenceClassification.from_pretrained(model_path).to(self.device)
        self.model.eval()
        
        # Load label mappings
        label_file = os.path.join(model_path, 'label_mappings.json')
        if os.path.exists(label_file):
            with open(label_file, 'r') as f:
                label_info = json.load(f)
                self.id_to_label = {int(k): v for k, v in label_info['id_to_label'].items()}
        else:
            self.id_to_label = {int(k): v for k, v in self.model.config.id2label.items()}
        
        print(f"Stance classifier loaded. Labels: {list(self.id_to_label.values())}")
    
    def predict(self, texts):
        """Predict stance for given texts"""
        if isinstance(texts, str):
            texts = [texts]
        
        inputs = self.tokenizer(
            texts,
            padding=True,
            truncation=True,
            max_length=256,
            return_tensors='pt'
        ).to(self.device)
        
        with torch.no_grad():
            logits = self.model(**inputs).logits
        
        predictions = logits.argmax(dim=-1).cpu().numpy()
        return [self.id_to_label[int(pred)] for pred in predictions]
    
    def predict_with_confidence(self, texts):
        """Predict stance with confidence scores"""
        if isinstance(texts, str):
            texts = [texts]
        
        inputs = self.tokenizer(
            texts,
            padding=True,
            truncation=True,
            max_length=256,
            return_tensors='pt'
        ).to(self.device)
        
        with torch.no_grad():
            logits = self.model(**inputs).logits
            probabilities = torch.softmax(logits, dim=-1)
        
        predictions = logits.argmax(dim=-1).cpu().numpy()
        confidence_scores = probabilities.max(dim=-1)[0].cpu().numpy()
        
        results = []
        for i, (pred, conf) in enumerate(zip(predictions, confidence_scores)):
            results.append({
                'text': texts[i],
                'stance': self.id_to_label[int(pred)],
                'confidence': float(conf)
            })
        
        return results

def test_stance_classifier():
    """Test the stance classifier with sample data"""
    
    model_path = '../models/stance_model_3050'
    if not os.path.exists(model_path):
        print(f"Model not found at {model_path}. Train the model first.")
        return
    
    # Initialize classifier
    classifier = StanceClassifier(model_path)
    
    # Test samples
    test_samples = [
        "I completely agree with this statement, it's absolutely true!",
        "This is completely false and misleading information",
        "Can someone verify if this claim is actually accurate?",
        "Just sharing this information for discussion purposes",
        "This news is terrible, but we need to spread awareness"
    ]
    
    print("\nTesting Stance Detection:")
    print("=" * 50)
    
    predictions = classifier.predict_with_confidence(test_samples)
    
    for result in predictions:
        print(f"Text: {result['text'][:60]}...")
        print(f"Stance: {result['stance']} (confidence: {result['confidence']:.3f})")
        print("-" * 50)

if __name__ == "__main__":
    # Train the stance detection model
    model_path = train_stance_detection_model()
    
    if model_path:
        print("\n" + "="*70)
        print("Testing the trained model...")
        test_stance_classifier()
    else:
        print("Training failed - cannot test model")
# Out:
# 🚀 GPU: NVIDIA GeForce RTX 3050 Laptop GPU
# 💾 GPU Memory: 4.0 GB
# 🔧 CUDA Version: 12.9
# Loading dataset for stance detection...
# 📊 Loaded dataset with 49666 rows
# 🎯 Using subset of 15000 rows for RTX 3050 VRAM limits
# ✅ Cleaned dataset: 15000 rows
# 📊 Stance distribution:
#   support: 13021 (86.8%)
#   deny: 1979 (13.2%)
# 🏷️ Stance labels: ['deny', 'support']
# 📊 Train: 12750, Val: 2250
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Tokenizing datasets...
# Map:   0%|          | 0/12750 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2250 [00:00<?, ? examples/s]
# ============================================================
# 🚀 TRAINING STANCE DETECTION MODEL (DistilBERT)
# ============================================================
#     <div>
#
#       <progress value='2128' max='2128' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2128/2128 10:23, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1 Macro</th>
#       <th>F1 Weighted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.239000</td>
#       <td>0.204072</td>
#       <td>0.931556</td>
#       <td>0.833134</td>
#       <td>0.927455</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.122700</td>
#       <td>0.165110</td>
#       <td>0.946222</td>
#       <td>0.874092</td>
#       <td>0.944232</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.078800</td>
#       <td>0.161377</td>
#       <td>0.951111</td>
#       <td>0.890498</td>
#       <td>0.950459</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.030000</td>
#       <td>0.192814</td>
#       <td>0.955111</td>
#       <td>0.898401</td>
#       <td>0.954268</td>
#     </tr>
#   </tbody>
# </table><p>
# ✅ Training completed successfully!
# 📊 Final Evaluation Results:
#   eval_loss: 0.1928
#   eval_accuracy: 0.9551
#   eval_f1_macro: 0.8984
#   eval_f1_weighted: 0.9543
#   eval_runtime: 15.0967
#   eval_samples_per_second: 149.0390
#   eval_steps_per_second: 9.3400
#   epoch: 4.0000
#
# ============================================================
# 📊 DETAILED EVALUATION
# ============================================================
# Classification Report:
#               precision    recall  f1-score   support
#
#         deny     0.8603    0.7879    0.8225       297
#      support     0.9681    0.9805    0.9743      1953
#
#     accuracy                         0.9551      2250
#    macro avg     0.9142    0.8842    0.8984      2250
# weighted avg     0.9539    0.9551    0.9543      2250
#
# 💾 Stance detection model saved to: ../models/stance_model_3050
# ✅ Stance detection training completed!
#
# ======================================================================
# Testing the trained model...
# Stance classifier loaded. Labels: ['deny', 'support']
#
# Testing Stance Detection:
# ==================================================
# Text: I completely agree with this statement, it's absolutely true...
# Stance: support (confidence: 0.966)
# --------------------------------------------------
# Text: This is completely false and misleading information...
# Stance: deny (confidence: 0.791)
# --------------------------------------------------
# Text: Can someone verify if this claim is actually accurate?...
# Stance: deny (confidence: 0.985)
# --------------------------------------------------
# Text: Just sharing this information for discussion purposes...
# Stance: support (confidence: 0.984)
# --------------------------------------------------
# Text: This news is terrible, but we need to spread awareness...
# Stance: support (confidence: 0.997)
# --------------------------------------------------
